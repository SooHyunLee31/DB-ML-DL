# %%
import numpy as np
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity="all"

# %%
import matplotlib.pyplot as plt
import platform

# %%
platform.system()
# Out:
# 'Windows'

# %%
# 그래프에서 한글폰트 지원
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    # path = "c:/Windows/Fonts/malgun.ttf"
    # font_name = font_manager.FontProperties(fname=path).get_name()
    # rc('font', family=font_name)
    rc('font', family='Malgun Gothic')
else:
    print('Unknown system...  sorry~~~')

# %%
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':
    plt.rcParams['font.family'] = 'AppleGothic'
else:
    plt.rcParams['font.family'] = 'NanumGothic' # 폰트를 사전 설치 필요

# %%
# 설치된 폰트 목록
import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name)
# Out:
# Yu Gothic
# Franklin Gothic Demi
# Franklin Gothic Book
# Franklin Gothic Book
# HYGothic-Medium
# Franklin Gothic Heavy
# Century Gothic
# Yu Gothic
# Franklin Gothic Medium Cond
# Century Gothic
# Showcard Gothic
# MS Gothic
# Franklin Gothic Demi Cond
# Franklin Gothic Medium
# Franklin Gothic Heavy
# Yu Gothic
# Century Gothic
# Malgun Gothic
# Malgun Gothic
# Copperplate Gothic Bold
# Copperplate Gothic Light
# HYGothic-Extra
# Century Gothic
# Yu Gothic
# Franklin Gothic Demi
# Franklin Gothic Medium
# Malgun Gothic

# %% [markdown]
# ## pandas의 plot으로 데이터 시각화

# %% [markdown]
# **pandas의 그래프기능 : matplotlib.pyplot 기반으로 만들어짐**
#
# https://pandas.pydata.org/docs/user_guide/visualization.html

# %% [markdown]
# #### 형식1.
# - Series_data.plot([kind='graph_kind'][, option])
#
#
# - DataFrame_data.plot([x=label 혹은 position, y=label 혹은 position,] [kind='graph_kind'][, option])
#
#
#
# - kind 옵션
#     - line : 선그래프
#     - scatter : 산점도(데이터프레임에서만 가능)
#     - bar : 수직막대그래프
#     - barh : 수평막대그래프
#     - hist : 히스토그램
#     - pie : 파이그래프
#     - box : 박스 플롯
#     - area : area 플롯
#     - density : Kernel Density Estimation 플롯
#     - kde : Kernel Density Estimation 플롯

# %% [markdown]
# #### 형식2.
#
#
# - 수직막대그래프
#     - Series_data.plot.bar([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.bar([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 수평막대그래프
#     - Series_data.plot.barh([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.barh([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 파이그래프
#     - Series_data.plot.pie([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.pie([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 선그래프
#     - Series_data.plot.line([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.line([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 히스토그램
#     - Series_data.plot.hist([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.hist([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 박스플롯
#     - Series_data.plot.box([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.box([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 산점도
#     - DataFrame_data.plot.scatter([x=label 혹은 position, y=label 혹은 position][, option])
#
#
# - 커널밀도추정곡선(Kernel Density Estimation)
#     - Series_data.plot.kde([x=label 혹은 position, y=label 혹은 position][, option])
#     - Series_data.plot.density([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.kde([x=label 혹은 position, y=label 혹은 position][, option])
#     - DataFrame_data.plot.density([x=label 혹은 position, y=label 혹은 position][, option])

# %% [markdown]
# ## 1. 범주형 데이터 시각화
#
# - 막대그래프, 파이그래프

# %% [markdown]
# #### 예. 타이타닉 데이터

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 1) 막대그래프(bar)

# %% [markdown]
# #### 타이타닉호 승객의 사망/생존 빈도

# %%
survived = df.Survived.value_counts()
survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
type(survived)
# Out:
# pandas.core.series.Series

# %%
survived.plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
survived.index=['사망','생존']
survived
# Out:
# 사망    549
# 생존    342
# Name: count, dtype: int64

# %%
# windows
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'NanumGothic'
# mac
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
survived.plot(kind='bar')
# Out:
# <Axes: >

# %%
survived.plot(kind='barh')
plt.show()

# %% [markdown]
# #### 타이타닉호 승객의 성별 사망/생존 비율

# %%
survived2 = np.round(df.Survived.value_counts(normalize=True)*100, 2)
survived2.index = ['사망', '생존']
survived2
# Out:
# 사망    61.62
# 생존    38.38
# Name: proportion, dtype: float64

# %%
survived2.plot.bar()
plt.show()

# %% [markdown]
# #### 타이타닉호 승객의 성별에 따른 사망/생존

# %%
df[['Sex', 'Survived']]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
survived3 = df[['Sex', 'Survived']].value_counts().sort_index()
survived3
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
type(survived3)
# Out:
# pandas.core.series.Series

# %%
# survived3.plot(kind='bar')
survived3.plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
survived3
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
survived4 = survived3.unstack()
survived4.rename(columns={0:'사망',1:'생존'}, inplace=True)
survived4
# Out:
# Survived   사망   생존
# Sex
# female     81  233
# male      468  109

# %%
type(survived4)
# Out:
# pandas.core.frame.DataFrame

# %%
survived4.plot.bar()
plt.show()

# %%
survived4.plot.bar(stacked=True)
plt.show()

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(10,4)),
                  columns='a b c d'.split())
df2
# Out:
#    a  b  c  d
# 0  4  3  6  5
# 1  3  0  9  9
# 2  4  6  9  0
# 3  3  7  8  1
# 4  0  6  8  4
# 5  9  9  0  6
# 6  6  8  3  4
# 7  0  9  1  5
# 8  9  4  4  8
# 9  0  7  1  5

# %%
df2.plot.bar()
plt.show()

# %%
df2.plot.bar(stacked=True)
plt.show()

# %% [markdown]
# => 데이터프레임에서 barplot을 그리면 x축은 인덱스, y축은 컬럼들을 동일한 인덱스에 묶어 그림

# %% [markdown]
# ### 2) 파이그래프(pie)

# %% [markdown]
# **타이타닉호 승객의 사망/생존 비율**

# %%
survived
# Out:
# 사망    549
# 생존    342
# Name: count, dtype: int64

# %%
survived.plot(kind='pie')
plt.show()

# %%
s = pd.Series(np.random.rand(4)*3, index='a b c d'.split(),
             name='Sample')
s
# Out:
# a    0.048294
# b    2.990178
# c    0.437454
# d    2.598139
# Name: Sample, dtype: float64

# %%
s.plot.pie()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
s.plot.pie(figsize=(4,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
s.plot.pie(figsize=(4,4),
          labels='A B C D'.split(),
           colors=['r', 'g', 'b', 'y'],
          autopct='%.2f%%',
          fontsize=8)
plt.show()

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(4,2))*3,
                  index='a b c d'.split(),
                  columns=['X','Y'])
df3
# Out:
#     X   Y
# a   3  21
# b  12  15
# c  18   6
# d  18  12

# %%
df3.plot.pie(subplots=True)
plt.show()

# %% [markdown]
# ## 2. 수치형 데이터 시각화
#
# - 선그래프, 히스토그램, 박스플롯, 산점도

# %% [markdown]
# ### 1) 히스토그램(histogram)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Age.plot(kind='hist')
plt.show()

# %%
df.Age.plot(kind='hist', figsize=(4,4))
plt.show()

# %%
df.Age.plot(kind='hist', figsize=(4,4), color='g')
plt.show()

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.plot(kind='hist', bins=8, figsize=(3,3))
plt.show()

# %%
df.Age.plot(kind='hist', bins=8, figsize=(3,3), xlabel='Age')
plt.show()

# %%
data = {'a':np.random.randn(1000) + 1,
       'b':np.random.randn(1000),
       'c':np.random.randn(1000) - 1}

df4 = pd.DataFrame(data)
df4.head()
# Out:
#           a         b         c
# 0 -0.012788 -0.156324 -1.641026
# 1  2.395206 -0.493725 -0.091618
# 2  1.826889 -1.941497 -2.293325
# 3  0.674572  0.262911 -1.236371
# 4  2.320780 -0.254261 -2.471510

# %%
df4.describe()
# Out:
#                  a            b            c
# count  1000.000000  1000.000000  1000.000000
# mean      0.991219    -0.026592    -0.990224
# std       1.002189     0.983463     0.943373
# min      -1.633898    -3.026418    -3.838434
# 25%       0.300177    -0.671905    -1.635116
# 50%       0.937946    -0.016365    -1.028873
# 75%       1.668229     0.645606    -0.371182
# max       4.483115     3.048331     2.065234

# %%
df4.plot.hist(figsize=(3.5,3.5))
plt.show()

# %%
df4.plot.hist(figsize=(3.5,3.5), alpha=0.5)
plt.show()

# %%
df4.plot.hist(figsize=(3.5,3.5), alpha=0.5, stacked=True)
plt.show()

# %%
df4['a'].plot.hist(figsize=(3.5,3.5), alpha=0.5)
plt.show()

# %%
df4['a'].plot.hist(figsize=(3.5,3.5), orientation='horizontal')
plt.show()

# %%
df4['a'].plot.hist(figsize=(3.5,3.5), cumulative=True, bins=30)
plt.show()

# %%
df4['a'].plot.hist(figsize=(3.5,3.5), bins=40)
plt.show()

# %%
df4.plot.hist(figsize=(3.5,6), subplots=True, cumulative=True)
plt.show()

# %% [markdown]
# ### 2) 박스플롯(box-plot)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Tukey : box and whisker plot(수염상자플롯)
# - lower hinge : Q1 - IQR*1.5
# - upper hinge : Q3 + IQG*1.5
# - Median : 50%
# - outlier (<lower-hinge) or (>upper-hinge)

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.plot(kind='box', figsize=(3.5,3.5))
plt.show()

# %%
df4.plot.box()
plt.show()

# %%
df5 = pd.DataFrame(np.random.rand(10,5),
                  columns='A B C D E'.split())
df5
# Out:
#           A         B         C         D         E
# 0  0.585129  0.535357  0.936043  0.087536  0.104182
# 1  0.883926  0.956655  0.085065  0.495376  0.589001
# 2  0.547479  0.284011  0.218540  0.994589  0.492595
# 3  0.919724  0.324675  0.203286  0.206348  0.697048
# 4  0.247071  0.991979  0.120267  0.245135  0.051985
# 5  0.067827  0.673827  0.337097  0.592624  0.828828
# 6  0.375045  0.767781  0.619820  0.244618  0.239459
# 7  0.718551  0.585251  0.189145  0.825179  0.136961
# 8  0.908494  0.675934  0.322266  0.077394  0.116534
# 9  0.799909  0.368470  0.598296  0.480202  0.970458

# %%
df5.plot.box(figsize=(5,3))
plt.show()

# %%
colors = {'boxes':'DarkGreen',
         'whiskers':'DarkOrange',
         'medians':'DarkBlue',
         'caps':'gray'}
df5.plot.box(color=colors, figsize=(5,3))
plt.show()

# %%
df5.plot.box(color=colors, figsize=(5,3), vert=False)
plt.show()

# %%
df5.plot.box(color=colors, figsize=(5,3), positions=[1,4,5,6,8])
plt.show()

# %% [markdown]
# ### 3) 선그래프(line)

# %% [markdown]
# **선 그래프는 시간별 추이,변화량을 비교할 때 사용**

# %%
df = pd.DataFrame({'경유' : [2100, 2050, 2000, 2010, 2150, 2090],
                    '휘발유': [1900, 1950, 1800, 1955, 1970, 1920]},
                   index = ['1월','2월','3월','4월','5월','6월'])
df
# Out:
#       경유   휘발유
# 1월  2100  1900
# 2월  2050  1950
# 3월  2000  1800
# 4월  2010  1955
# 5월  2150  1970
# 6월  2090  1920

# %%
df.plot(figsize=(5,3))
plt.show()

# %%
df.경유.plot(figsize=(5,3))
plt.show()

# %%
df_nflx = pd.read_csv('data/NFLX.csv')
df_nflx.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df_nflx['Date'] = pd.to_datetime(df_nflx['Date'])
df_nflx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4874 entries, 0 to 4873
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4874 non-null   datetime64[ns]
#  1   Open       4874 non-null   float64
#  2   High       4874 non-null   float64
#  3   Low        4874 non-null   float64
#  4   Close      4874 non-null   float64
#  5   Adj Close  4874 non-null   float64
#  6   Volume     4874 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 266.7 KB

# %%
df = df_nflx.set_index('Date')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4874 entries, 2002-05-23 to 2021-09-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4874 non-null   float64
#  1   High       4874 non-null   float64
#  2   Low        4874 non-null   float64
#  3   Close      4874 non-null   float64
#  4   Adj Close  4874 non-null   float64
#  5   Volume     4874 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 266.5 KB

# %%
df['Open'].plot()
plt.show()

# %% [markdown]
# #### 새로운 색인 지정(reindex)
#
# - 새로운 색인에 적합하도록 객체를 생성
# - 시계열과 같은 순차적인 데이터를 재색인 하는 경우 등

# %%
index = ['Firefox', 'Chrome', 'Safari', 'IE10', 'Konqueror']
df = pd.DataFrame({'http_status': [200, 200, 404, 404, 301],
                   'response_time': [0.04, 0.02, 0.07, 0.08, 1.0]},
                   index=index)
new_index = ['Safari', 'Iceweasel', 'Comodo Dragon', 'IE10', 'Chrome']
df
# Out:
#            http_status  response_time
# Firefox            200           0.04
# Chrome             200           0.02
# Safari             404           0.07
# IE10               404           0.08
# Konqueror          301           1.00

# %%
df.reindex(new_index)
# Out:
#                http_status  response_time
# Safari               404.0           0.07
# Iceweasel              NaN            NaN
# Comodo Dragon          NaN            NaN
# IE10                 404.0           0.08
# Chrome               200.0           0.02

# %%
df.reindex(new_index, fill_value=0)
# Out:
#                http_status  response_time
# Safari                 404           0.07
# Iceweasel                0           0.00
# Comodo Dragon            0           0.00
# IE10                   404           0.08
# Chrome                 200           0.02

# %%
df.reindex(new_index, fill_value='missing')
# Out:
#               http_status response_time
# Safari                404          0.07
# Iceweasel         missing       missing
# Comodo Dragon     missing       missing
# IE10                  404          0.08
# Chrome                200          0.02

# %%
df.reindex(columns=['http_status', 'user_agent'], fill_value=0)
# Out:
#            http_status  user_agent
# Firefox            200           0
# Chrome             200           0
# Safari             404           0
# IE10               404           0
# Konqueror          301           0

# %%
s = pd.DataFrame(['blue', 'purple', 'yellow'], index=[0,2,4])
s
# Out:
#         0
# 0    blue
# 2  purple
# 4  yellow

# %%
s.reindex(np.arange(6))
# Out:
#         0
# 0    blue
# 1     NaN
# 2  purple
# 3     NaN
# 4  yellow
# 5     NaN

# %%
s.reindex(np.arange(6), method='ffill')
# Out:
#         0
# 0    blue
# 1    blue
# 2  purple
# 3  purple
# 4  yellow
# 5  yellow

# %%
s.reindex(np.arange(6), method='bfill')
# Out:
#         0
# 0    blue
# 1  purple
# 2  purple
# 3  yellow
# 4  yellow
# 5     NaN

# %%
date_index = pd.date_range('1/1/2010', periods=6, freq='D')
df2 = pd.DataFrame({"prices": [100, 101, np.nan, 100, 89, 88]},
                  index=date_index)
df2
# Out:
#             prices
# 2010-01-01   100.0
# 2010-01-02   101.0
# 2010-01-03     NaN
# 2010-01-04   100.0
# 2010-01-05    89.0
# 2010-01-06    88.0

# %%
date_index2 = pd.date_range('12/29/2009', periods=10, freq='D')
df2.reindex(date_index2)
# Out:
#             prices
# 2009-12-29     NaN
# 2009-12-30     NaN
# 2009-12-31     NaN
# 2010-01-01   100.0
# 2010-01-02   101.0
# 2010-01-03     NaN
# 2010-01-04   100.0
# 2010-01-05    89.0
# 2010-01-06    88.0
# 2010-01-07     NaN

# %% [markdown]
# ### 4) 산점도(scatterplot)

# %% [markdown]
# **산점도(scatter plot) : 두 변수간의 상관성**

# %%
data = {'height' : [165, 177, 160, 180, 185, 155, 172],
        'weight' : [62, 67, 55, 74, 90, 43, 64]}
df = pd.DataFrame(data)
df
# Out:
#    height  weight
# 0     165      62
# 1     177      67
# 2     160      55
# 3     180      74
# 4     185      90
# 5     155      43
# 6     172      64

# %%
df.plot(kind='scatter', x='height', y='weight', figsize=(3,3))
plt.show()

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.plot.scatter(x='sepal_length', y='petal_length', figsize=(4,4))
plt.show()

# %%
iris.species = iris.species.astype('category')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
iris.plot.scatter(x='sepal_length', y='petal_length', figsize=(4,4),
                 c='species', cmap='viridis')
plt.show()

# %% [markdown]
# ### 5) 산점도 행렬(scatterplot matrix)

# %%
from pandas.plotting import scatter_matrix

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.iloc[:,:-1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
scatter_matrix(iris.iloc[:,:-1])
plt.show()

# %%
# !pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    ----- ---------------------------------- 5.2/40.9 MB 26.5 MB/s eta 0:00:02
#    ------------------------- -------------- 26.5/40.9 MB 67.0 MB/s eta 0:00:01
#    ---------------------------------------  40.4/40.9 MB 65.8 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 66.6 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 45.7 MB/s eta 0:00:00
# ...

# %%
scatter_matrix(iris.iloc[:,:-1], diagonal='kde')
plt.show()

# %% [markdown]
# ### 6) 밀도함수(density plot)

# %%
s = pd.Series(np.random.randn(1000))
s.mean(), s.std()
# Out:
# (np.float64(-0.00889139832880408), np.float64(0.9957956398657425))

# %%
s.plot.kde(figsize=(5,3))
plt.show()

# %% [markdown]
# ### 7) 평행좌표 플롯(parallel coordinate plot)

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(iris, 'species')
plt.show()

# %% [markdown]
# -------------
